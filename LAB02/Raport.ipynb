# %% [markdown]
# # Laboratori 02 — Git dhe GitHub
#
# Kursi: Hyrje në laborator
# Studenti: Bjorn Muca
# Data: 2026-03-24
# Profesori i lendes : Ervin Kafexhiu

# %% [markdown]
# ## Qëllimi
#
# Qëllimi i këtij laboratori është të kuptohet përdorimi i Git dhe GitHub për menaxhimin e projekteve dhe versioneve të kodit.

# %% [markdown]
# ## Teoria
#
# Git është një sistem për kontrollin e versioneve që lejon ruajtjen dhe menaxhimin e ndryshimeve në kod.
#
# GitHub është një platformë online që përdoret për të ruajtur repository dhe për të bashkëpunuar me të tjerë.
#
# Komandat kryesore janë:
# - git init
# - git add
# - git commit
# - git push
# - git pull

# %% [markdown]
# ## Metoda
#
# Në këtë laborator u krijua një repository dhe u kryen veprimet bazë të Git për menaxhimin e skedarëve dhe versioneve.

# %%
# simulim i nje sistemi versionimi
versions = ["v1", "v2", "v3"]
print("Versionet e projektit:", versions)
# Out:
# Versionet e projektit: ['v1', 'v2', 'v3']

# %% [markdown]
# ## Rezultatet
#
# U demonstrua përdorimi i Git për menaxhimin e ndryshimeve dhe organizimin e projekteve.

# %% [markdown]
# ## Përfundimi
#
# Git dhe GitHub janë mjete të rëndësishme për zhvillimin e softuerit dhe bashkëpunimin në projekte.
