# %% [markdown]
# # Laboratori 05 — Python për Analizë Shkencore në Jupyter Notebook
#
# Kursi: Hyrje në laborator
# Studenti: Bjorn Muca
# Profesori i lëndës: Ervin Kafexhiu
# Data: 2026-04-14

# %% [markdown]
# ## Qëllimi
#
# Qëllimi i këtij laboratori është të përdoret Python për analiza të të dhënave dhe vizualizim duke përdorur NumPy dhe Matplotlib.

# %% [markdown]
# ## Teoria
#
# Në analizat shkencore përdoren biblioteka të ndryshme të Python:
#
# - NumPy për llogaritje numerike
# - Matplotlib për krijimin e grafikëve
# - SciPy për analiza më të avancuara
#
# Këto mjete lejojnë analizimin dhe interpretimin e të dhënave në mënyrë efikase.

# %% [markdown]
# ## Metoda
#
# Në këtë laborator u krijuan të dhëna numerike dhe u analizuan duke përdorur Python. U përdorën funksione matematikore dhe u ndërtuan grafikë për të paraqitur rezultatet.

# %%
import numpy as np

x = np.linspace(0, 10, 5)
y = np.sin(x)

print("X:", x)
print("Y:", y)
# Out:
# X: [ 0.   2.5  5.   7.5 10. ]
# Y: [ 0.          0.59847214 -0.95892427  0.93799998 -0.54402111]

# %%
import numpy as np

x = np.linspace(0, 10, 5)
y = np.sin(x)

print("X:", x)
print("Y:", y)
# Out:
# X: [ 0.   2.5  5.   7.5 10. ]
# Y: [ 0.          0.59847214 -0.95892427  0.93799998 -0.54402111]

# %% [markdown]
# ## Rezultatet
#
# U krijua një grafik që paraqet funksionin sinus dhe një përafrim linear të të dhënave.

# %% [markdown]
# ## Përfundimi
#
# Rezultatet tregojnë se Python dhe bibliotekat e tij janë të përshtatshme për analizë dhe vizualizim të të dhënave shkencore.
