# %% [markdown]
# # Laboratori 03 — Markdown dhe Struktura e Raportit Laboratorik
#
# Kursi: Hyrje në laborator
# Studenti: Bjorn Muca
# Data: 2026-03-17

# %% [markdown]
# ## Qëllimi
#
# Qëllimi i këtij laboratori është të mësohet përdorimi i Markdown në Jupyter Notebook për krijimin e raporteve të strukturuara.

# %% [markdown]
# ## Titujt (Headings)
#
# # Titull kryesor
# ## Seksion
# ### Nënseksion

# %% [markdown]
# ## Formatimi i Tekstit
#
# **Tekst i trashë**
# *Tekst italic*
#
# Ky është një shembull teksti me formatim Markdown.

# %% [markdown]
# ## Listat
#
# ### Lista me pika:
# - Matjet
# - Analiza
# - Përfundimi
#
# ### Lista e numëruar:
# 1. Përgatitja e eksperimentit
# 2. Kryerja e matjeve
# 3. Analiza e të dhënave

# %% [markdown]
# ## Formulat Matematikore
#
# Formula brenda tekstit: $F = ma$
#
# Formula në rresht të veçantë:
#
# $$
# x(t) = x_0 + v_0 t + \frac{1}{2} a t^2
# $$

# %% [markdown]
# ## Linke
#
# Dokumentacioni i Python:
# https://www.python.org

# %% [markdown]
# ## Struktura e një Raporti
#
# Një raport laboratorik përmban:
#
# - Titulli
# - Objektivi
# - Teoria
# - Metoda
# - Analiza e të dhënave
# - Rezultatet
# - Përfundimi

# %% [markdown]
# ## Përfundimi
#
# Në këtë laborator u mësua përdorimi i Markdown për të strukturuar një raport laboratorik në mënyrë të qartë dhe të organizuar.
