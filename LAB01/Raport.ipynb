# %% [markdown]
# # Laboratori 01 — Hyrje në JupyterLab dhe Mjedisin e Punës
#
# Kursi: Hyrje në laborator
# Studenti: Bjorn Muca
# Data: 2026-03-17
# Profesori i lendes : Ervin Kafexhiu

# %% [markdown]
# ## Qëllimi
#
# Në këtë notebook do të dokumentoj:
#
# 1. Konfigurimin e environment-it "lab"
# 2. Nisjen e JupyterLab dhe krijimin e notebook-ut
# 3. Ekzekutimin e qelizave
# 4. Një test minimal me Python/NumPy/Matplotlib

# %% [markdown]
# ## Lista e kontrollit (Checklist)
#
# - Miniconda/Anaconda e instaluar
# - Mjedisi "lab" i krijuar
# - JupyterLab nis pa probleme
# - Qelizat e kodit ekzekutohen (Shift+Enter)
# - Notebook u ruajt dhe u ngarkua në GitHub

# %%
print("Hello Jupyter")
# Out:
# Hello Jupyter

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [1,4,9,16]

plt.plot(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Grafik test")
plt.show()

# %% [markdown]
# ## Përfundimi
#
# Në këtë laborator u mësua përdorimi i Jupyter Notebook dhe krijimi i një raporti që kombinon tekst dhe kod.
